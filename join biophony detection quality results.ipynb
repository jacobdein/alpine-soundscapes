# %% [markdown]
# # join biophony detection quality results

# %%
import pandas

# %%
data_path = r"C:\Users\JDDein\OneDrive\Documents\alpine soundscapes\data\dataset_r.csv"

# %%
quality_path = r"C:\Users\JDDein\OneDrive\Documents\alpine soundscapes\data\biophony_detection_quality.csv"

# %%
data = pandas.read_csv(data_path).set_index('sound')
quality = pandas.read_csv(quality_path).set_index('sound')

# %%
data_quality = data.join(quality)

# %%
data_quality
# Out:
#        site           site_name        sel  biophony       week  temperature  \
# sound
# 102      15           Hofgarten -52.597239  3.190989   3.000000          6.7
# 103      26        Bienenstraße -39.485967  1.059628   3.000000          6.7
# 104       5         Gumppstraße -42.121012  1.833383   3.000000          6.6
# 105      21         Templstraße -36.444121  0.400789   3.000000          6.5
# 106      18  Egger-Lienz-Straße -33.970066  1.215006   3.000000          6.2
# ...     ...                 ...        ...       ...        ...          ...
# 247      30          Wittenberg -50.237237  7.183681  13.285714         17.7
# 248      13       Andreas-Hofer -52.664278  5.344868  13.285714         18.2
# 250      20              Wilten -36.254316  0.364063  13.285714         18.5
# 251      15           Hofgarten -42.322308  1.934042  13.714286          8.9
# 147       7      Höttinger Rain -49.905715  1.415632   5.142857          3.2
#
# ...

# %%
data_quality.groupby('quality').count()
# Out:
#          site  site_name  sel  biophony  week  temperature  wind_speed  \
# quality
# 0          64         64   64        64    64           64          64
# 1          42         42   42        42    42           42          42
# 2          19         19   19        19    19           19          19
#
#          precipitation  pressure  bus_stop  ...  d2n_5m  d2n_10m  d2n_20m  \
# quality                                     ...
# 0                   64        64        64  ...      64       64       64
# 1                   42        42        42  ...      42       42       42
# 2                   19        19        19  ...      19       19       19
#
#          d2n_40m  d2n_80m  d2n_160m  d2n_320m  d2n_640m  d2n_1280m  d2n_2560m
# quality
# 0             64       64        64        64        64         64         64
# 1             42       42        42        42        42         42         42
# 2             19       19        19        19        19         19         19
#
# ...
